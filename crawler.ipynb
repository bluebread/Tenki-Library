# %%
from datetime import datetime, date, timedelta
import re
from urllib.request import urlopen

from selenium import webdriver
from bs4 import BeautifulSoup as BS
import numpy as np
from pandas import DataFrame, date_range, concat, read_csv, Series, datetime

# %%
browser = webdriver.Chrome()
browser.get("http://www.tenki.jp/past/2017/12/13/1/1/47407.html")

html = browser.find_element_by_tag_name("body").get_attribute('innerHTML')

bsObj = BS(html, 'lxml')
table = bsObj.find("table", {"class": "past_live_point_table"}).tbody.extract()

# %%
url = "http://www.tenki.jp/past/2018/01/?map_area_id=5"
browser.get(url)
html = browser.find_element_by_tag_name("body").get_attribute('innerHTML')

bs_obj = BS(html, 'lxml')
table = bs_obj.find("table", {
    "class": "amedas_pref_point_entries_table"
}).extract()

# %%
def area_code_list():
    columns_attrs = ["big_area", "mid_area", "sml_area", "place_code"]
    df_list = []
    for area_id in range(1, 11):
        table = get_area_table(area_id)
        area_code = extract_area_code_data(area_id, table)
        c_df = DataFrame(area_code, columns=columns_attrs)
        df_list.append(c_df)
    area_df = concat(df_list, ignore_index=True)

    return area_df

# %%
def get_area_table(area_id):
    url = "http://www.tenki.jp/past/2018/01/?map_area_id={0}".format(area_id)
    browser.get(url)
    html = browser.find_element_by_tag_name("body").get_attribute('innerHTML')

    bs_obj = BS(html, 'lxml')
    table = bs_obj.find("table", {
        "class": "amedas_pref_point_entries_table"
    }).extract()

    return table

# %%
def extract_area_code_data(area_id, table):
    area_code = []
    tbody = table.tbody
    big_area_name = table['summary'].split(' ')[0]

    for mida in tbody.children:
        try:
            mida_tag = mida.th.a
            smla_tags = mida.td
        except AttributeError:
            continue

        for smla_a in smla_tags.contents:
            try:
                clu = smla_a['href']
                pcode = get_place_code(clu, area_id)
                area_data = [
                    big_area_name,
                    mida_tag.get_text(),
                    smla_a.get_text(), pcode
                ]
                area_code.append(area_data)
            except TypeError:
                continue

    return area_code

# %%
area_code_list()
# Out:
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# ...

# %%
date(2016,1,1) + timedelta(2) < date(2016,1,3)
date(2016,1,1).year
date(2016,2,1).month
date(2016,1,3).day
# Out:
# 3

# %%
save = []
for i in range(1,11):
    url = 'http://www.tenki.jp/past/2018/01/?map_pref_id={0}'.format(i)
    browser.get(url)
    cur_url = browser.current_url
    save.append(cur_url[-5:])

# %%
save
# Out:
# ['47407',
#  '47412',
#  '47418',
#  '47430',
#  '47575',
#  '47584',
#  '47590',
#  '47582',
#  '47588',
#  '47595']

# %%
pattern1 = r'map_pref_id=[0-9]?[0-9]'
pattern2 = r'jma_code=\d{5}'
p = '\d{5}'
l = re.search(pattern2, "/past/2018/01/?map_pref_id=3&jma_code=47418").group(0)
re.search(p, l).group(0)
# Out:
# '47418'

# %%
def get_place_code(clue, area_id):
    map_re = r'map_pref_id=[0-9]?[0-9]'
    jma_re = r'jma_code=\d{5}'
    map_v_re = r'[0-9]?[0-9]'
    jma_v_re = r'\d{5}'
    map_param = re.search(map_re, clue).group(0)
    jam_param = re.search(jma_re, clue).group(0)
    map_pref_id = re.search(map_v_re, map_param).group(0)
    jam_code = re.search(jma_v_re, jam_param).group(0)

    return "{0}/{1}/{2}".format(area_id, map_pref_id, jam_code)

# %%
get_place_code("/past/2018/01/?map_pref_id=1&jma_code=47407", 1)
# Out:
# '1/1/47407'

# %%
entry_dict = {
    "weather_entry": "天気",
    "total_cloud_cover_entry": "雲量",
    "ceiling_entry": '雲底高度',
    "temp_entry": '気温(℃)',
    "humidity_entry": '湿度(%)',
    "dp_temp_entry": '露点温度(℃)',
    "precip_entry": '3時間降水量',
    "pressure_change_entry": '現地気圧(hPa)',
    "pressure_entry": '現地気圧(hPa)(変化量)',
    "sea_level_pressure_entry": '海面気圧(hPa)',
    "wind_direction_entry": '風向(16方位)',
    "wind_speed_entry": '風速(m/s)',
    "visibility_entry": '視程(km)',
    "discomfort_index_entry": '不快指数',
}

# %%
first_en = table.find("td", class_="weather_entry")
first_en.next_sibling.get_text()
# Out:
# 'にわか雪'

# %%
day_weather = []
attrs= entry_dict.values()
for attr, jname in entry_dict.items():
    first_en = table.find("td", class_=attr)
    en_row = [first_en.get_text()]
    for en in first_en.next_siblings:
        try:
            en_row.append(en.get_text())
        except AttributeError:
            pass
    day_weather.append(en_row)

# %%
attrs = entry_dict.values()

# %%
time_index = [["2016-12-13"] * 8, [3, 6, 9, 12, 15, 18, 21, 24]]
cols = [["ulala"]*14,["ls"]*14 ,list(attrs)]
a = DataFrame(np.array(day_weather).T, columns=cols, index=time_index)
cols = [[1]*14,[1]*7+[2]*7 ,list(attrs)]
b = DataFrame(np.array(day_weather).T, columns=cols, index=time_index)
a.index.names=['date', 'hour']
a
# a.columns.names = ['fir', 'sec', 'thi']
# a.to_csv("test.csv", encoding="cp932")
# Out:
#                 ulala                                                  \
#                    ls
#                    天気    雲量 雲底高度 気温(℃) 湿度(%) 露点温度(℃) 3時間降水量 現地気圧(hPa)
# date       hour
# 2016-12-13 3     にわか雪   隙間無  ---  -4.8    91    -6.0    3.5     984.1
#            6     にわか雪   隙間無  ---  -4.5    93    -5.4    1.0     985.8
#            9       曇り   隙間無  ---  -2.4    74    -6.4    0.0     987.0
#            12      曇り  9割以上  ---  -1.3    74    -5.3    0.0     986.6
#            15    にわか雪   隙間無  ---  -2.1    91    -3.4    0.0     987.6
#            18    にわか雪   隙間無  ---  -2.3    91    -3.6    0.5     989.6
#            21      曇り   隙間無  ---  -3.2    96    -3.7    0.0     992.0
#            24     ---   ---  ---  -2.3    90    -3.7    0.5     994.2
#
#
#
#                 現地気圧(hPa)(変化量) 海面気圧(hPa) 風向(16方位) 風速(m/s) 視程(km) 不快指数
# date       hour
# 2016-12-13 3            (+2.0)    1001.8        南       3    1.5   34
# ...

# %%
dateparse = lambda d: datetime.strptime(d, '%Y-%m-%d')
k = read_csv("test.csv", encoding="cp932", header=[0,1,2], index_col=[0,1], parse_dates=[0], date_parser=dateparse)
k['ulala','ls','天気']
# Out:
# date        hour
# 2016-12-13  3       にわか雪
#             6       にわか雪
#             9         曇り
#             12        曇り
#             15      にわか雪
#             18      にわか雪
#             21        曇り
#             24       ---
# Name: (ulala, ls, 天気), dtype: object

# %%
dateparse = lambda d: datetime.strptime(d, '%Y, %m, %d')
k = read_csv("fast_place_weather.csv", encoding="cp932",  header=[0,1,2,3], index_col=[0,1], parse_dates=[0], date_parser=dateparse)
k#['北海道地方','道北','旭川', '天気']['2016-01-01' :'2016-01-02']
# Out:
# D:\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2698: DtypeWarning: Columns (6,7,13,15,34,35,42,43,48,49,56,57,61,62,63,65,67,69,70,71,76,77,85,89,90,91,92,93,95,98,99,126,145,146,147,149,151,154,155,160,161,162,168,169,188,189,190,191,193,196,197,202,203,207,211,218,230,231,238,239,257,258,259,260,261,263,265,266,267,271,272,273,275,277,279,281,286,287,295,308,314,315,323,336,342,343,344,350,351,364,392,406,425,426,427,431,434,435,454,455,463,476,481,482,483,484,487,489,490,491,496,497,505,509,510,511,512,515,517,518,519,532,538,539,540,546,547,552,553,561,574,580,581,582,588,589,594,595,602,603,621,622,623,624,625,627,631,663,664,665,667,669,672,673,686,705,706,707,708,709,711,713,714,715,728,762,763,769,770,771,783,803,804,805,811,812,813,818,819,827,831,832,833,837,840,841,845,846,847,849,851,853,854,855,859,860,861,862,863,865,868,869,873,874,875,876,877,881,882,883,888,889,897,902,903,909,911,918,924,930,931,939,943,952,974,986,987,995,999,1000,1001,1005,1008,10
# ...

# %%
concat([a,b],axis=1)[1]
np.array(day_weather).T.shape
[i for i in range(3,25,3)]
"1".zfill(2)
# Out:
# '01'

# %%
for index, row in read_csv("area_code.csv", encoding="cp932").iterrows():
    print(row['place_code'])
# read_csv("area_code.csv", encoding="cp932")
# Out:
# 1/1/47407
# 1/1/47401
# 1/1/47402
# 1/1/47404
# 1/1/47406
# 1/3/47418
# 1/3/47420
# 1/3/47409
# 1/3/47405
# 1/3/47417
# 1/3/47435
# 1/3/47440
# 1/2/47412
# 1/2/47413
# 1/2/47411
# 1/2/47421
# 1/2/47433
# 1/4/47430
# 1/4/47426
# 1/4/47424
# 1/4/47423
# 1/4/47428
# 2/5/47575
# 2/5/47581
# 2/5/47574
# 2/5/47576
# 2/6/47584
# 2/6/47585
# 2/6/47512
# 2/7/47590
# 2/7/47592
# 2/8/47582
# 2/9/47588
# 2/9/47587
# 2/9/47520
# 2/10/47595
# 2/10/47598
# 2/10/47570
# 2/10/47597
# 3/16/47662
# 3/16/47675
# 3/16/47677
# 3/16/47678
# 3/16/47971
# 3/16/47991
# 3/17/47670
# 3/14/47626
# 3/14/47641
# 3/15/47682
# 3/15/47648
# 3/15/47672
# 3/15/47674
# 3/11/47629
# 3/12/47615
# 3/12/47690
# 3/13/47624
# 3/22/47638
# 3/22/47640
# 3/23/47610
# 3/23/47618
# 3/23/47620
# 3/23/47637
# 3/23/47622
# 4/18/47604
# 4/18/47612
# 4/18/47602
# 4/19/47607
# 4/19/47606
# 4/20/47605
# 4/20/47600
# 4/21/47616
# 4/21/47631
# 5/26/47636
# 5/26/47653
# 5/24/47632
# 5/24/47617
# 5/25/47656
# 5/25/47654
# 5/25/47655
# ...

# %%
date(2016,1,1).strftime("%Y, %m, %d")
# Out:
# '2016, 01, 01'

# %%
import time
time.sleep(5)
print('d')
# Out:
# d

# %%
try:
    x.y = 0
except AttributeError as err:
    try:
        k = 8
    except:
        pass
else:
    y=2
    
k
# Out:
# 8

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-213-73517e632a66> in <module>()
# ----> 1 raise AttributeError("aa")
#
# AttributeError: aa

# %%
raise Warning("lala")
# Out:
# ---------------------------------------------------------------------------
# Warning                                   Traceback (most recent call last)
# <ipython-input-220-026174c2e962> in <module>()
# ----> 1 raise Warning("lala")
#
# ...

# %%
s1 = DataFrame(['a', 'b'], index=[["la",0],[0,0]])

s2 = DataFrame(['c', 'd'], index=[[0,"la"],[0,1]])
concat([s1, s2],axis=1, ignore_index=True)
# Out:
#         0    1
# la 0    a  NaN
# 0  0    b    c
# la 1  NaN    d

# %%
pw_df = read_csv("place_weather.csv", encoding="cp932")

# %%
pw_df
# Out:
#    北海道地方 北海道地方.1 北海道地方.2 北海道地方.3 北海道地方.4  北海道地方.5 北海道地方.6    北海道地方.7  \
# 0     道北      道北      道北      道北      道北       道北      道北         道北
# 1     旭川      旭川      旭川      旭川      旭川       旭川      旭川         旭川
# 2     天気      雲量    雲底高度   気温(℃)   湿度(%)  露点温度(℃)  3時間降水量  現地気圧(hPa)
# 3   にわか雪    9割以上     ---    -4.4      89     -5.9     0.5     1001.1
# 4   にわか雪    9割以上     ---    -4.5      94     -5.3     0.0     1001.7
# 5   にわか雪    9割以上     ---    -4.1      87     -5.9     0.5     1003.1
# 6   にわか雪    9割以上     ---    -3.0      78     -6.3     0.0     1003.3
# 7     晴れ      6割     ---    -3.0      71     -7.5     0.0     1004.0
# 8   にわか雪    9割以上     ---    -3.8      79     -6.9     0.0     1005.0
# 9   にわか雪    9割以上     ---    -3.9      76     -7.5     0.0     1003.5
# 10   ---     ---     ---    -3.8      81     -6.6     0.5     1002.2
#
#            北海道地方.8    北海道地方.9   ...    沖縄地方.102 沖縄地方.103 沖縄地方.104   沖縄地方.105  \
# ...

# %%
datetime.today().strftime("%b %d %Y %H:%M:%S")
# Out:
# 'Jan 30 2018 20:38:32'

# %%
ac_df = read_csv('area_code.csv',encoding='cp932')
area = ac_df['mid_area'].unique()[0]
ac_df[ac_df['mid_area'] == area].iloc[0]
# Out:
# big_area          北海道地方
# mid_area             道北
# sml_area             旭川
# place_code    1/1/47407
# Name: 0, dtype: object

# %%
js = urlopen("http://az416740.vo.msecnd.net/component/static_api/past/live/2016/02/01/point_47407.js")
i = eval(js.read()[15:-1].decode('utf-8'))

# 'b'+js.read()[15:-1].decode('utf-8')
# k = js.read()[16:-2]
# k
bsObj = BS(i, "lxml")
bsObj.find('table', class_='past_live_point_table').tbody

# %%
"2313".zfill(2)
# Out:
# '2313'

# %%
"1/1/47189"[-5:]
# Out:
# '47189'

# %%
read_csv("area_code.csv", encoding="cp932").shape
# Out:
# (154, 4)

# %%
js = urlopen("http://az416740.vo.msecnd.net/component/static_api/past/live/2016/02/01/point_47407.js")
'\u003c!'
# Out:
# '<!'

# %%
pw_df = read_csv("fast_place_weather.csv", encoding="cp932")
pw_df
# Out:
#               date  hour    天気    雲量 雲底高度  気温(℃) 湿度(%) 露点温度(℃)  3時間降水量  \
# 0     2016, 01, 01     3  にわか雪  9割以上  ---   -4.4    89    -5.9     0.5
# 1     2016, 01, 01     6  にわか雪  9割以上  ---   -4.5    94    -5.3     0.0
# 2     2016, 01, 01     9  にわか雪  9割以上  ---   -4.1    87    -5.9     0.5
# 3     2016, 01, 01    12  にわか雪  9割以上  ---   -3.0    78    -6.3     0.0
# 4     2016, 01, 01    15    晴れ    6割  ---   -3.0    71    -7.5     0.0
# 5     2016, 01, 01    18  にわか雪  9割以上  ---   -3.8    79    -6.9     0.0
# 6     2016, 01, 01    21  にわか雪  9割以上  ---   -3.9    76    -7.5     0.0
# 7     2016, 01, 01    24   ---   ---  ---   -3.8    81    -6.6     0.5
# 8     2016, 01, 02     3  にわか雪  9割以上  ---   -2.6    74    -6.6     0.0
# 9     2016, 01, 02     6    曇り  9割以上  ---   -1.2    71    -5.8     0.0
# 10    2016, 01, 02     9  にわか雪  9割以上  ---   -0.4    84    -2.8     0.0
# 11    2016, 01, 02    12  にわか雪   隙間無  ---   -0.3    94    -1.1     0.0
# ...
